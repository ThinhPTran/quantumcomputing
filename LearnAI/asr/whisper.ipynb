# %%
import whisper

model = whisper.load_model("turbo", device="cpu")
result = model.transcribe("nguyen-ngoc-ngan.wav")
print(result["text"])
# Out:
# /Users/mac/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Điểm thứ hai mà chúng tôi cũng xin thưa quý vị là Cũng trong cái buổi nói chuyện đó thì tôi có đề cập tới một phụ nữ Việt Nam Đã sống tại Mỹ 17 năm mà bị trục xuất Thì thưa quý vị bản tin này chúng tôi cũng đọc ở trên báo hoặc là trên mạng Nhưng mà không có kiểm chứng chi tiết cho chính xác trước khi lên đường qua Âu Trọng Thì chúng tôi xin rút lại câu chuyện này để tránh sự hiểu lầm về chính sách di trú của Hoa Kỳ Thưa quý vị

# %%
model = whisper.load_model("tiny")
result = model.transcribe("nguyen-ngoc-ngan.wav")
print(result["text"])
# Out:
# /Users/mac/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Để mấy mấy mấy trục xuất, tất cả việc bản tin này, chúng ta cũng đọc ở trên báo vàc ở trên báo, nhưng mà không có kiểm trứng, chỉ tiếp cho chính xác trước khi lên đường qua ủng trọc, chúng ta sẽ xin dút lại câu chuyện này để chẳng sự hiệu lắm về chính xác gì chủ của hã kệ.

# %%
model = whisper.load_model("base")
result = model.transcribe("nguyen-ngoc-ngan.wav")
print(result["text"])
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:06<00:00, 23.9MiB/s]
# /Users/mac/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Đếm thứ hai, chúng tôi cũng xin thưa với cái vị là Cũng trong cái bối nói chuyện đó thì tôi có để cập tới một phụ nữ Việt Nam đã xấu tại biệt Mỹ 17 năm mà bị chốt sốt thì tôi cái vị bản tin này chúng tôi cũng đọc ở trên báo hoặc là trên mạng nhưng mà không có kiểm chứng chí tiết cho chính xác trước khi lên đường của au chập thì chúng tôi xin rút lại câu chuyện này để chánh sự hiểu lầm để chính xác dì chú của hoa kịt

# %%
model = whisper.load_model("small")
result = model.transcribe("nguyen-ngoc-ngan.wav")
print(result["text"])
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:37<00:00, 13.0MiB/s]
# /Users/mac/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Điểm thứ hai mà chúng tôi cũng xin thưa với quý vị là cũng trong cái bồi nói chuyện đó, tôi có thể cập tới một phụ nữ Việt Nam đã sống tại Mỹ 17 năm mà bị chục xuất. Thì tôi quý vị bản tin này, chúng tôi cũng đọc ở trên báo hoặc trên mạng, nhưng mà không có kiểm chứng, chi tiết cho chính xác trước khi lên đường qua Âu Châu, thì chúng tôi xin rút lại câu chuyện này để tránh sự hiểu lầm về chính xác di trú của Hoa Kịch. Tôi cùng về...

# %%
model = whisper.load_model("medium")
result = model.transcribe("nguyen-ngoc-ngan.wav")
print(result["text"])
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [01:18<00:00, 19.4MiB/s]
# /Users/mac/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Điểm thứ 2 mà chúng tôi cũng xin thưa với quý vị là, trong bộ nói chuyện đó tôi cũng đề cập tới một phụ nữ Việt Nam đã sống tại Mỹ 17 năm mà bị trục xuất. Bản tin này chúng tôi cũng đọc ở trên báo hoặc trên mạng, nhưng mà không có kiểm chứng chi tiết cho chính xác trước khi lên đường qua Âu Trọng. Chúng tôi xin rút lại câu chuyện này để tránh sự hiểu lầm về chính xác di trú của Hoa Kịch. Thưa quý vị,

# %%
model = whisper.load_model("tiny")
result = model.transcribe("nguyen-ngoc-ngan.wav")
print(result["text"])
# Out:
# /Users/mac/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Để mấy mấy mấy trục xuất, tất cả việc bản tin này, chúng ta cũng đọc ở trên báo vàc ở trên báo, nhưng mà không có kiểm trứng, chỉ tiếp cho chính xác trước khi lên đường qua ủng trọc, chúng ta sẽ xin dút lại câu chuyện này để chẳng sự hiệu lắm về chính xác gì chủ của hã kệ.

# %%
model = whisper.load_model("large-v3")
result = model.transcribe("nguyen-ngoc-ngan.wav")
print(result["text"])
# Out:
# /Users/mac/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  Điểm thứ hai mà chúng tôi cũng xin thưa với quý vị là Cũng trong cái buổi nói chuyện đó thì tôi có đề cập tới một phụ nữ Việt Nam đã sống tại Mỹ 17 năm mà bị trục xuất Thì thưa quý vị bản tin này chúng tôi cũng đọc ở trên báo hoặc là trên mạng Nhưng mà không có kiểm chứng chi tiết cho chính xác trước khi lên đường qua Âu Chồng Thì chúng tôi xin rút lại câu chuyện này để tránh sự hiểu lầm về chính sách di trú của Hoa Kỳ Thưa quý vị

# %%
model = whisper.load_model("tiny")
result = model.transcribe("Training Kondor.m4a")
print(result["text"])
# Out:
# /Users/mac/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 model = whisper.load_model("tiny")
# ----> 2 result = model.transcribe("Training Kondor.m4a")
#       3 print(result["text"])
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:295, in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, carry_initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, clip_timestamps, hallucination_silence_threshold, **decode_options)
#     292 else:
#     293     decode_options["prompt"] = all_tokens[prompt_reset_since:]
# --> 295 result: DecodingResult = decode_with_fallback(mel_segment)
#     296 tokens = torch.tensor(result.tokens)
#     298 if no_speech_threshold is not None:
#     299     # no voice activity check
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/transcribe.py:201, in transcribe.<locals>.decode_with_fallback(segment)
#     198     kwargs.pop("best_of", None)
#     200 options = DecodingOptions(**kwargs, temperature=t)
# --> 201 decode_result = model.decode(segment, options)
#     203 needs_fallback = False
#     204 if (
#     205     compression_ratio_threshold is not None
#     206     and decode_result.compression_ratio > compression_ratio_threshold
#     207 ):
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/decoding.py:824, in decode(model, mel, options, **kwargs)
#     821 if kwargs:
#     822     options = replace(options, **kwargs)
# --> 824 result = DecodingTask(model, options).run(mel)
#     826 return result[0] if single else result
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/decoding.py:737, in DecodingTask.run(self, mel)
#     734 tokens = tokens.repeat_interleave(self.n_group, dim=0).to(audio_features.device)
#     736 # call the main sampling loop
# --> 737 tokens, sum_logprobs, no_speech_probs = self._main_loop(audio_features, tokens)
#     739 # reshape the tensors to have (n_audio, n_group) as the first two dimensions
#     740 audio_features = audio_features[:: self.n_group]
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/decoding.py:687, in DecodingTask._main_loop(self, audio_features, tokens)
#     685 try:
#     686     for i in range(self.sample_len):
# --> 687         logits = self.inference.logits(tokens, audio_features)
#     689         if (
#     690             i == 0 and self.tokenizer.no_speech is not None
#     691         ):  # save no_speech_probs
#     692             probs_at_sot = logits[:, self.sot_index].float().softmax(dim=-1)
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/decoding.py:163, in PyTorchInference.logits(self, tokens, audio_features)
#     159 if tokens.shape[-1] > self.initial_token_length:
#     160     # only need to use the last token except in the first forward pass
#     161     tokens = tokens[:, -1:]
# --> 163 return self.model.decoder(tokens, audio_features, kv_cache=self.kv_cache)
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/model.py:242, in TextDecoder.forward(self, x, xa, kv_cache)
#     239 x = x.to(xa.dtype)
#     241 for block in self.blocks:
# --> 242     x = block(x, xa, mask=self.mask, kv_cache=kv_cache)
#     244 x = self.ln(x)
#     245 logits = (
#     246     x @ torch.transpose(self.token_embedding.weight.to(x.dtype), 0, 1)
#     247 ).float()
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/model.py:170, in ResidualAttentionBlock.forward(self, x, xa, mask, kv_cache)
#     168 if self.cross_attn:
#     169     x = x + self.cross_attn(self.cross_attn_ln(x), xa, kv_cache=kv_cache)[0]
# --> 170 x = x + self.mlp(self.mlp_ln(x))
#     171 return x
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Programming/Python/myvir309/lib/python3.9/site-packages/whisper/model.py:46, in Linear.forward(self, x)
#      45 def forward(self, x: Tensor) -> Tensor:
# ---> 46     return F.linear(
#      47         x,
#      48         self.weight.to(x.dtype),
#      49         None if self.bias is None else self.bias.to(x.dtype),
#      50     )
#
# KeyboardInterrupt:
