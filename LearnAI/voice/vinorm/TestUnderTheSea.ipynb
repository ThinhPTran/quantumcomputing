# %%
from underthesea import text_normalize
norm_text = text_normalize("Ðảm baỏ chất lựơng phòng thí nghịêm hoá học")
print(norm_text)
# Out:
# Đảm bảo chất lượng phòng thí nghiệm hóa học

# %%
from vinorm import TTSnorm
S=TTSnorm("Ðảm baỏ chất lựơng phòng thí nghịêm hoá học")
print(S)
# Out:
# baỏ chất lựơng phòng thí nghịêm hoá học.

# %%
from vinorm import TTSnorm
S=TTSnorm("Hàm này được phát triển từ tháng 8/2019. Có phải tháng 12/2020 đã có vaccine phòng ngừa Covid-19 xmz ?")

print(S)
# Out:
# hàm này được phát triển từ tháng tám năm hai nghìn không trăm mười chín . có phải tháng mười hai năm hai nghìn không trăm hai mươi đã có vaccine phòng ngừa covid mười chín xmz ..

# %%
from underthesea import text_normalize
norm_text1 = text_normalize("Hàm này được phát triển từ tháng 8/2019. Có phải tháng 12/2020 đã có vaccine phòng ngừa Covid-19 xmz ?")
print(norm_text1)
# Out:
# Hàm này được phát triển từ tháng 8/2019 . Có phải tháng 12/2020 đã có vaccine phòng ngừa Covid-19 xmz ?

# %%
from underthesea import text_normalize
from vinorm import TTSnorm
norm_text1 = text_normalize("Hàm này được phát triển từ tháng 8/2019. Có phải tháng 12/2020 đã có vaccine phòng ngừa Covid-19 xmz ?")
norm_text = TTSnorm(norm_text1)
print(norm_text)
# Out:
# hàm này được phát triển từ tháng tám năm hai nghìn không trăm mười chín . có phải tháng mười hai năm hai nghìn không trăm hai mươi đã có vaccine phòng ngừa covid mười chín xmz ..

# %%
from underthesea import text_normalize
from vinorm import TTSnorm
norm_text1 = text_normalize("vitamin")
norm_text = TTSnorm(norm_text1)

from viphoneme import vi2IPA_split
delimit ="/"
phonemes = vi2IPA_split(norm_text, delimit)
print(phonemes)
# Out:
# vitamin/ /./ /./  /./
