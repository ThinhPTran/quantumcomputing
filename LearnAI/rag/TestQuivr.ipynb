# %%
  import tempfile

  from quivr_core import Brain

  if __name__ == "__main__":
      with tempfile.NamedTemporaryFile(mode="w", suffix=".txt") as temp_file:
          temp_file.write("Gold is a liquid of blue-like colour.")
          temp_file.flush()

          brain = Brain.from_files(
              name="test_brain",
              file_paths=[temp_file.name],
          )

          answer = brain.ask(
              "what is gold? asnwer in french"
          )
          print("answer:", answer)
# Out:
# /Users/mac/Programming/Python/myvir311/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:918: UserWarning: Mixing V1 models and V2 models (or constructs, like `TypeAdapter`) is not supported. Please upgrade `BasePromptTemplate` to V2.
#   warn(
# /Users/mac/Programming/Python/myvir311/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:918: UserWarning: Mixing V1 models and V2 models (or constructs, like `TypeAdapter`) is not supported. Please upgrade `BaseTool` to V2.
#   warn(
# The API key for supplier 'DefaultModelSuppliers.OPENAI' is not set.
# Please set the environment variable: 'OPENAI_API_KEY'.
# The API key for supplier 'DefaultModelSuppliers.OPENAI' is not set.
# Please set the environment variable: 'OPENAI_API_KEY'.
# The API key for supplier 'DefaultModelSuppliers.OPENAI' is not set.
# Please set the environment variable: 'OPENAI_API_KEY'.
# /Users/mac/Programming/Python/myvir311/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:918: UserWarning: Mixing V1 models and V2 models (or constructs, like `TypeAdapter`) is not supported. Please upgrade `ChatMessage` to V2.
#   warn(
# /Users/mac/Programming/Python/myvir311/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:918: UserWarning: Mixing V1 models and V2 models (or constructs, like `TypeAdapter`) is not supported. Please upgrade `Document` to V2.
#   warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 10
#       7 temp_file.write("Gold is a liquid of blue-like colour.")
#       8 temp_file.flush()
# ---> 10 brain = Brain.from_files(
#      11     name="test_brain",
#      12     file_paths=[temp_file.name],
#      13 )
#      15 answer = brain.ask(
#      16     "what is gold? asnwer in french"
#      17 )
#      18 print("answer:", answer)
#
# File ~/Programming/Python/myvir311/lib/python3.11/site-packages/quivr_core/brain/brain.py:384, in Brain.from_files(cls, name, file_paths, vector_db, storage, llm, embedder, skip_file_error, processor_kwargs)
#     370 @classmethod
#     371 def from_files(
#     372     cls,
#    (...)    381     processor_kwargs: dict[str, Any] | None = None,
#     382 ) -> Self:
#     383     loop = asyncio.get_event_loop()
# --> 384     return loop.run_until_complete(
#     385         cls.afrom_files(
#     386             name=name,
#     387             file_paths=file_paths,
#     388             vector_db=vector_db,
#     389             storage=storage,
#     390             llm=llm,
#     391             embedder=embedder,
#     392             skip_file_error=skip_file_error,
#     393             processor_kwargs=processor_kwargs,
#     394         )
#     395     )
#
# File /opt/homebrew/Cellar/python@3.11/3.11.13/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py:630, in BaseEventLoop.run_until_complete(self, future)
#     619 """Run until the Future is done.
#     620
#     621 If the argument is a coroutine, it is wrapped in a Task.
#    (...)    627 Return the Future's result, or raise its exception.
#     628 """
#     629 self._check_closed()
# --> 630 self._check_running()
#     632 new_task = not futures.isfuture(future)
#     633 future = tasks.ensure_future(future, loop=self)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.13/Frameworks/Python.framework/Versions/3.11/lib/python3.11/asyncio/base_events.py:589, in BaseEventLoop._check_running(self)
#     587 def _check_running(self):
#     588     if self.is_running():
# --> 589         raise RuntimeError('This event loop is already running')
#     590     if events._get_running_loop() is not None:
#     591         raise RuntimeError(
#     592             'Cannot run the event loop while another loop is running')
#
# RuntimeError: This event loop is already running
